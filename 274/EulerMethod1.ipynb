# %%
#Euler Method Python Program

#Right hand side goes here: y'=f(x,y)

import numpy as np

def f(x,y):
    return x**2-3*x*y-3*y+y**2

#Euler Method

def euler(x0, y0, xn, n):
    
    #calculate steps/step size
    n = int((xn-x0)/step)
    h = step
    
    print('\n----------------Solution------------------')
    print('-----------------------------------------')
    print('x0\ty0\tslope\tyn')
    print('------------------------------------------')
    for i in range(n):
        slope = f(x0,y0)
        yn = y0 + h*slope
        print('%.4f\t%.4f\t%0.4f\t%.4f'% (x0,y0,slope,yn))
        print('-------------------------------------')
        y0 = yn
        x0 = x0 + h
        
    print('\nAt x=%.4f, y=%.4f' % (xn,yn))
    
    

    
    
#Inputs
print('Enter initial conditions')
x0 = float(input('x0= '))
y0 = float(input('y0= '))

print('Enter calculation point: ')
xn = float(input('xn = '))

print('Enter step size:')
step = float(input('h = '))

#Euler Method Call
euler(x0,y0,xn,step)
# Out:
# Enter initial conditions
# x0= 0
# y0= 2
# Enter calculation point:
# xn = 3
# Enter step size:
# h = 0.1
#
# ----------------Solution------------------
# -----------------------------------------
# x0	y0	slope	yn
# ------------------------------------------
# 0.0000	2.0000	-2.0000	1.8000
# -------------------------------------
# 0.1000	1.8000	-2.6900	1.5310
# -------------------------------------
# 0.2000	1.5310	-3.1276	1.2182
# -------------------------------------
# 0.3000	1.2182	-3.1770	0.9005
# -------------------------------------
# 0.4000	0.9005	-2.8113	0.6194
# -------------------------------------
# 0.5000	0.6194	-2.1537	0.4040
# -------------------------------------
# 0.6000	0.4040	-1.4161	0.2624
# -------------------------------------
# 0.7000	0.2624	-0.7795	0.1845
# -------------------------------------
# 0.8000	0.1845	-0.3221	0.1523
# -------------------------------------
# 0.9000	0.1523	-0.0347	0.1488
# -------------------------------------
# 1.0000	0.1488	0.1294	0.1617
# -------------------------------------
# 1.1000	0.1617	0.2173	0.1835
# -------------------------------------
# 1.2000	0.1835	0.2628	0.2097
# -------------------------------------
# 1.3000	0.2097	0.2868	0.2384
# -------------------------------------
# 1.4000	0.2384	0.3002	0.2684
# -------------------------------------
# 1.5000	0.2684	0.3087	0.2993
# -------------------------------------
# 1.6000	0.2993	0.3149	0.3308
# -------------------------------------
# 1.7000	0.3308	0.3199	0.3628
# -------------------------------------
# 1.8000	0.3628	0.3241	0.3952
# -------------------------------------
# 1.9000	0.3952	0.3279	0.4280
# -------------------------------------
# 2.0000	0.4280	0.3312	0.4611
# -------------------------------------
# 2.1000	0.4611	0.3342	0.4945
# -------------------------------------
# 2.2000	0.4945	0.3370	0.5282
# -------------------------------------
# 2.3000	0.5282	0.3395	0.5622
# -------------------------------------
# 2.4000	0.5622	0.3418	0.5964
# -------------------------------------
# 2.5000	0.5964	0.3439	0.6307
# -------------------------------------
# 2.6000	0.6307	0.3458	0.6653
# -------------------------------------
# 2.7000	0.6653	0.3476	0.7001
# -------------------------------------
# 2.8000	0.7001	0.3492	0.7350
# -------------------------------------
# 2.9000	0.7350	0.3507	0.7701
# -------------------------------------
#
# At x=3.0000, y=0.7701
